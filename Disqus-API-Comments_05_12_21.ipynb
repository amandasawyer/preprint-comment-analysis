# %%
#import necessary libraries
import requests
import json
import numpy as np
import pandas as pd
from csv import reader
import re

# %% [markdown]
# ## Reading in PMID List and Preparing Data

# %%
#read in list of PMIDs from sample
PMIDlist = pd.read_csv('pmids-journal.csv')
PMIDlist
# Out:
#          PMID       PMCID                          DOI  Journal  Total_Posts  \
# 0    33052356  PMC7553173  10.1101/2020.10.07.20208231  medrxiv           33
# 1    33052353  PMC7553167  10.1101/2020.10.08.20209650  medrxiv          329
# 2    33052363  PMC7553188  10.1101/2020.10.02.20204859  medrxiv            6
# 3    33052360  PMC7553180  10.1101/2020.10.05.20206953  medrxiv            4
# 4    33052359  PMC7553179  10.1101/2020.10.07.20208488  medrxiv           32
# ..        ...         ...                          ...      ...          ...
# 995  32511426  PMC7217033  10.1101/2020.03.06.20032417  medrxiv           21
# 996  32511424  PMC7216959  10.1101/2020.02.21.20026328  medrxiv          117
# 997  32511423  PMC7216908  10.1101/2020.02.09.20021261  medrxiv          235
# 998  32511422  PMC7216848  10.1101/2020.01.28.20019224  medrxiv           86
# 999  32511421  PMC7216847  10.1101/2020.02.05.20020750  medrxiv           51
#
#      Tweeters  Media  Videos  Facebook  Google_Plus  Reddit  Blogs  \
# 0          33    NaN     NaN       NaN          NaN     NaN    NaN
# 1         243   29.0     NaN       NaN          NaN     NaN    6.0
# 2           6    NaN     NaN       NaN          NaN     NaN    NaN
# 3           4    NaN     NaN       NaN          NaN     NaN    NaN
# 4          30    1.0     NaN       NaN          NaN     NaN    NaN
# ..        ...    ...     ...       ...          ...     ...    ...
# 995        20    NaN     NaN       NaN          NaN     NaN    NaN
# 996       111    NaN     NaN       NaN          NaN     NaN    NaN
# 997       205    9.0     NaN       NaN          NaN     NaN    2.0
# 998        67    7.0     NaN       NaN          NaN     NaN    1.0
# 999        43    1.0     NaN       NaN          NaN     NaN    NaN
#
#      Altmetric_Score                                            URL
# 0             19.250  http://dx.doi.org/10.1101/2020.10.07.20208231
# 1            396.800  http://dx.doi.org/10.1101/2020.10.08.20209650
# 2              2.250  http://dx.doi.org/10.1101/2020.10.02.20204859
# 3              1.750  http://dx.doi.org/10.1101/2020.10.05.20206953
# 4             25.550  http://dx.doi.org/10.1101/2020.10.07.20208488
# ..               ...                                            ...
# 995           12.950  http://dx.doi.org/10.1101/2020.03.06.20032417
# 996           66.150  http://dx.doi.org/10.1101/2020.02.21.20026328
# 997          234.980  http://dx.doi.org/10.1101/2020.02.09.20021261
# 998          106.622  http://dx.doi.org/10.1101/2020.01.28.20019224
# 999           44.250  http://dx.doi.org/10.1101/2020.02.05.20020750
#
# [1000 rows x 14 columns]

# %%
#collects preprint server for each pmid. doesn't return medrxiv, only biorxiv. so all blank results are medrxiv.
def getJournal(pmid):
    noComment = 0
    journal = []
    try:
        requestLink = 'https://api.altmetric.com/v1/pmid/' + str(pmid)
        response = requests.get(requestLink)
        data = response.json()
        journal = data['journal']
    except : pass
    return journal


PMIDlist['Journal'] = PMIDlist['PMID'].apply(getJournal)
PMIDlist['Journal'] = PMIDlist['Journal'].astype(str)

# %%
#put all journals in lowercase before creating urls
PMIDlist['Journal'] = PMIDlist['Journal'].str.lower()

# %%
#create url using dois and journals
PMIDlist['URL'] = 'https://www.' + PMIDlist['Journal'].astype('str') + '.org/content/' + PMIDlist['DOI'].astype('str') + 'v1'
PMIDlist['Journal'] = PMIDlist['Journal'].replace({'biorxiv' : 'biorxivstage'})

# %% [markdown]
# ## Collecting and Storing Comments

# %%
#function for getting request given a forum and link
def getDisqusComments (forum, link) :
    requestLink = 'https://disqus.com/api/3.0/threads/listPosts.json?forum=' + forum +'&thread=link%3a'+ link +'&api_key='+'UpxKr5429gnFZBeZgy1lzFyjD5BYu2DnQEukxi5KpdNHzBSYY0g1dtfrrBAIib3r'
    response = requests.get(requestLink)
    data = response.json()
    return data

# %%
#collect comments. errorCount variable tests to make sure all comments are found
results_list = []
errorCount = 0

for index, row in PMIDlist.iterrows():
    d = row.to_dict()
    json = getDisqusComments(d['Journal'], d['URL'])
    if json['code'] == 0 :
        list_prep = json['response'].copy()
        results_list.append(list_prep)
    else :
        errorCount += 1

# %%
errorCount
# Out:
# 0

# %%
#empty dataframe for storing results
data = pd.DataFrame(columns=['author', 'canVote', 'createdAt', 'dislikes', 'editableUnitl', 'forum', 'id', 'isApproved',
                           'isAtFlagLimit', 'isDeleted', 'isDeletedByAuthor', 'isEdited', 'isFlagged', 'isHighlighted', 'isSpam',
                           'likes', 'media', 'message', 'moderationLabels', 'numReports', 'parent', 'points', 'raw_message',
                           'sb', 'thread'])

# %%
#iterate through list to place comments into dataframe
for i in results_list:
    if bool(i) == True:
        data = data.append(i, sort=False)
    else :
        pass

# %%
#view comment dataframe
data
# Out:
#                                                author canVote  \
# 0   {'username': 'jennifergoldfarb', 'about': '', ...   False
# 0   {'username': 'glipsnort', 'about': 'Geneticist...   False
# 1   {'username': 'disqus_qe356HFV5Z', 'about': '',...   False
# 0   {'username': 'disqus_NgAANDJMma', 'about': '',...   False
# 0   {'username': 'disqus_9yn7Y6RUwm', 'about': '',...   False
# ..                                                ...     ...
# 0   {'username': 'coniinthegarden', 'about': '', '...   False
# 1   {'username': 'disqus_3eLBJohjJJ', 'about': '',...   False
# 2   {'username': 'steve_gelfand', 'about': '', 'na...   False
# 3   {'username': 'sunrydz', 'about': '', 'name': '...   False
# 4   {'username': 'disqus_0ZnajuSp9p', 'about': '',...   False
#
#               createdAt dislikes  editableUnitl         forum          id  \
# 0   2020-10-21T01:15:29        0            NaN  biorxivstage  5118418045
# 0   2020-09-24T19:07:43        0            NaN       medrxiv  5083844729
# 1   2020-09-24T14:55:10        0            NaN       medrxiv  5083489431
# 0   2020-10-05T12:42:45        0            NaN  biorxivstage  5098043003
# 0   2020-11-03T04:48:03        0            NaN  biorxivstage  5135634790
# ..                  ...      ...            ...           ...         ...
# 0   2020-07-16T23:25:03        0            NaN       medrxiv  4994780081
# 1   2020-06-06T00:06:57        0            NaN       medrxiv  4942740436
# 2   2020-05-10T03:27:47        0            NaN       medrxiv  4908001814
# 3   2020-05-08T16:24:34        0            NaN       medrxiv  4906210750
# 4   2020-04-21T09:07:53        0            NaN       medrxiv  4883652858
#
#    isApproved isAtFlagLimit isDeleted  ... media  \
# 0        True         False     False  ...    []
# 0        True         False     False  ...    []
# 1        True         False     False  ...    []
# 0        True         False     False  ...    []
# 0        True         False     False  ...    []
# ..        ...           ...       ...  ...   ...
# 0        True         False     False  ...    []
# 1        True         False     False  ...    []
# 2        True         False     False  ...    []
# 3        True         False     False  ...    []
# 4        True         False     False  ...    []
#
#                                               message moderationLabels  \
# 0   <p>I am a graduate student at Johns Hopkins an...               []
# 0   <p>The paper reports that Rh-positive blood ty...               []
# 1   <p>Enjoyable reading,  instructive work, I war...          [links]
# 0   <p><a href="https://disq.us/url?url=https%3A%2...          [links]
# 0   <p>We have recently published the structural w...          [links]
# ..                                                ...              ...
# 0   <p>It is still important as means of slowing t...               []
# 1   <p>Although I agree with you that it's pointle...               []
# 2   <p>It’s all about doing what you can to reduce...               []
# 3   <p>If this virus can survive in the air for so...               []
# 4   <p>At last, bravi! In Italy now they cannot sa...               []
#
#    numReports        parent points  \
# 0           0           NaN      0
# 0           0           NaN      0
# 1           0           NaN      1
# 0           0           NaN      0
# 0           0           NaN      0
# ..        ...           ...    ...
# 0           0  4906210750.0      0
# 1           0  4906210750.0      0
# 2           0  4906210750.0      1
# 3           0           NaN      2
# 4           0           NaN      1
#
#                                           raw_message     sb      thread  \
# 0   I am a graduate student at Johns Hopkins and i...  False  8227042830
# 0   The paper reports that Rh-positive blood type ...  False  8213393965
# 1   Enjoyable reading,  instructive work, I warmly...  False  8213393965
# 0   https://www.immunology.ox.ac.uk/covid-19/covid...  False  8211385649
# 0   We have recently published the structural work...  False  8209714272
# ..                                                ...    ...         ...
# 0   It is still important as means of slowing the ...  False  7977087794
# 1   Although I agree with you that it's pointless ...  False  7977087794
# 2   It’s all about doing what you can to reduce vi...  False  7977087794
# 3   If this virus can survive in the air for so lo...  False  7977087794
# 4   At last, bravi! In Italy now they cannot say m...  False  7977087794
#
#           editableUntil
# 0   2020-10-28T01:15:29
# 0   2020-10-01T19:07:43
# 1   2020-10-01T14:55:10
# 0   2020-10-12T12:42:45
# 0   2020-11-10T04:48:03
# ..                  ...
# 0   2020-07-23T23:25:03
# 1   2020-06-13T00:06:57
# 2   2020-05-17T03:27:47
# 3   2020-05-15T16:24:34
# 4   2020-04-28T09:07:53
#
# [494 rows x 26 columns]

# %%
#save comments to local folder
data.to_csv('Disqus-comments.csv', index = False)

# %% [markdown]
# ## Collecting PMIDs to Reconnect Comments to Articles

# %%
#function for getting request given a forum and link
def getlinks (forum, thread) :
    requestLink = 'https://disqus.com/api/3.0/threads/details.json?forum=' + forum + '&thread=' + thread +'&api_key='+'jlac3sVtiBaBstx1LfetUFTjYr1sEvhdlLD9To3LEV6lpuVTcCnxX4LX8gaQfNOn'
    response = requests.get(requestLink)
    data = response.json()
    link = data['response']['link']
    return link

# %%
#testing function on one article
getlinks('medrxiv', '8213393965')
# Out:
# 'https://www.medrxiv.org/content/10.1101/2020.09.22.20199125v1'

# %%
#use function to collect article links
data['article_link'] = np.vectorize(getlinks)(data['forum'], data['thread'])

# %%
#get DOI from Disqus article links so that we can merge back with PMIDs
#getDOI function removes all link content prior to DOI and the concluding period
#replaceV1 removes v1 from the end of the link

def getDOI(x) :
    doi = re.search(r'(?<=content/).*[^. ]', x)
    return doi.group(0)

data['DOI'] = data['article_link'].apply(getDOI)
def replaceV1 (x) :
    return x.replace('v1', '')
data['DOI'] = data['DOI'].apply(replaceV1)
data['DOI']

# %%
#Full outer join to merge original PMID list with comments
final_df = pd.merge(PMIDlist, data, left_on='DOI', right_on='DOI', how='outer')

# %%
#Preview final dataframe
final_df
# Out:
#           PMID       PMCID                          DOI  Journal  Total_Posts  \
# 0     33052356  PMC7553173  10.1101/2020.10.07.20208231  medrxiv           33
# 1     33052353  PMC7553167  10.1101/2020.10.08.20209650  medrxiv          329
# 2     33052363  PMC7553188  10.1101/2020.10.02.20204859  medrxiv            6
# 3     33052360  PMC7553180  10.1101/2020.10.05.20206953  medrxiv            4
# 4     33052359  PMC7553179  10.1101/2020.10.07.20208488  medrxiv           32
# ...        ...         ...                          ...      ...          ...
# 1283  32511426  PMC7217033  10.1101/2020.03.06.20032417  medrxiv           21
# 1284  32511424  PMC7216959  10.1101/2020.02.21.20026328  medrxiv          117
# 1285  32511423  PMC7216908  10.1101/2020.02.09.20021261  medrxiv          235
# 1286  32511422  PMC7216848  10.1101/2020.01.28.20019224  medrxiv           86
# 1287  32511421  PMC7216847  10.1101/2020.02.05.20020750  medrxiv           51
#
#       Tweeters  Media  Videos  Facebook  Google_Plus  ...  message  \
# 0           33    NaN     NaN       NaN          NaN  ...      NaN
# 1          243   29.0     NaN       NaN          NaN  ...      NaN
# 2            6    NaN     NaN       NaN          NaN  ...      NaN
# 3            4    NaN     NaN       NaN          NaN  ...      NaN
# 4           30    1.0     NaN       NaN          NaN  ...      NaN
# ...        ...    ...     ...       ...          ...  ...      ...
# 1283        20    NaN     NaN       NaN          NaN  ...      NaN
# 1284       111    NaN     NaN       NaN          NaN  ...      NaN
# 1285       205    9.0     NaN       NaN          NaN  ...      NaN
# 1286        67    7.0     NaN       NaN          NaN  ...      NaN
# 1287        43    1.0     NaN       NaN          NaN  ...      NaN
#
#       moderationLabels  numReports parent points raw_message   sb thread  \
# 0                  NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 1                  NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 2                  NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 3                  NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 4                  NaN         NaN    NaN    NaN         NaN  NaN    NaN
# ...                ...         ...    ...    ...         ...  ...    ...
# 1283               NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 1284               NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 1285               NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 1286               NaN         NaN    NaN    NaN         NaN  NaN    NaN
# 1287               NaN         NaN    NaN    NaN         NaN  NaN    NaN
#
#       editableUntil article_link
# 0               NaN          NaN
# 1               NaN          NaN
# 2               NaN          NaN
# 3               NaN          NaN
# 4               NaN          NaN
# ...             ...          ...
# 1283            NaN          NaN
# 1284            NaN          NaN
# 1285            NaN          NaN
# 1286            NaN          NaN
# 1287            NaN          NaN
#
# [1288 rows x 41 columns]

# %%
#remove superfluous comments unrelated to this project
final_df = final_df.drop(['Total_Posts', 'Tweeters', 'Media', 'Videos', 'Facebook', 'Google_Plus', 'Altmetric_Score', 'dislikes', 'Reddit', 'Blogs', 'canVote', 'likes', 'media', 'moderationLabels', 'numReports', 'points', 'sb', 'editableUntil'], axis=1)

# %%
final_df
# Out:
#           PMID       PMCID                          DOI  Journal  \
# 0     33052356  PMC7553173  10.1101/2020.10.07.20208231  medrxiv
# 1     33052353  PMC7553167  10.1101/2020.10.08.20209650  medrxiv
# 2     33052363  PMC7553188  10.1101/2020.10.02.20204859  medrxiv
# 3     33052360  PMC7553180  10.1101/2020.10.05.20206953  medrxiv
# 4     33052359  PMC7553179  10.1101/2020.10.07.20208488  medrxiv
# ...        ...         ...                          ...      ...
# 1283  32511426  PMC7217033  10.1101/2020.03.06.20032417  medrxiv
# 1284  32511424  PMC7216959  10.1101/2020.02.21.20026328  medrxiv
# 1285  32511423  PMC7216908  10.1101/2020.02.09.20021261  medrxiv
# 1286  32511422  PMC7216848  10.1101/2020.01.28.20019224  medrxiv
# 1287  32511421  PMC7216847  10.1101/2020.02.05.20020750  medrxiv
#
#                                                     URL author createdAt  \
# 0     https://www.medrxiv.org/content/10.1101/2020.1...    NaN       NaN
# 1     https://www.medrxiv.org/content/10.1101/2020.1...    NaN       NaN
# 2     https://www.medrxiv.org/content/10.1101/2020.1...    NaN       NaN
# 3     https://www.medrxiv.org/content/10.1101/2020.1...    NaN       NaN
# 4     https://www.medrxiv.org/content/10.1101/2020.1...    NaN       NaN
# ...                                                 ...    ...       ...
# 1283  https://www.medrxiv.org/content/10.1101/2020.0...    NaN       NaN
# 1284  https://www.medrxiv.org/content/10.1101/2020.0...    NaN       NaN
# 1285  https://www.medrxiv.org/content/10.1101/2020.0...    NaN       NaN
# 1286  https://www.medrxiv.org/content/10.1101/2020.0...    NaN       NaN
# 1287  https://www.medrxiv.org/content/10.1101/2020.0...    NaN       NaN
#
#       editableUnitl forum   id  ... isDeletedByAuthor isEdited isFlagged  \
# 0               NaN   NaN  NaN  ...               NaN      NaN       NaN
# 1               NaN   NaN  NaN  ...               NaN      NaN       NaN
# 2               NaN   NaN  NaN  ...               NaN      NaN       NaN
# 3               NaN   NaN  NaN  ...               NaN      NaN       NaN
# 4               NaN   NaN  NaN  ...               NaN      NaN       NaN
# ...             ...   ...  ...  ...               ...      ...       ...
# 1283            NaN   NaN  NaN  ...               NaN      NaN       NaN
# 1284            NaN   NaN  NaN  ...               NaN      NaN       NaN
# 1285            NaN   NaN  NaN  ...               NaN      NaN       NaN
# 1286            NaN   NaN  NaN  ...               NaN      NaN       NaN
# 1287            NaN   NaN  NaN  ...               NaN      NaN       NaN
#
#      isHighlighted isSpam message parent raw_message thread article_link
# 0              NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 1              NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 2              NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 3              NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 4              NaN    NaN     NaN    NaN         NaN    NaN          NaN
# ...            ...    ...     ...    ...         ...    ...          ...
# 1283           NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 1284           NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 1285           NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 1286           NaN    NaN     NaN    NaN         NaN    NaN          NaN
# 1287           NaN    NaN     NaN    NaN         NaN    NaN          NaN
#
# [1288 rows x 23 columns]

# %%
#save a local copy of dataframe as csv
final_df.to_csv('Disqus-comments-all-articles.csv', index = False)
